# %%
import pandas as pd
import gzip
import json

# %%
def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)
        
def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient = 'index')

# %%
df = getDF('Movies_and_TV_5.json.gz')

# %%
df
# Out:
#          overall  verified   reviewTime      reviewerID        asin  \
# 0            5.0      True   11 9, 2012  A2M1CU2IRZG0K9  0005089549
# 1            5.0      True  12 30, 2011   AFTUJYISOFHY6  0005089549
# 2            5.0      True  04 21, 2005  A3JVF9Y53BEOGC  000503860X
# 3            5.0      True   04 6, 2005  A12VPEOEZS1KTC  000503860X
# 4            5.0      True   12 3, 2010   ATLZNVLYKP9AZ  000503860X
# ...          ...       ...          ...             ...         ...
# 3410014      4.0      True   01 1, 2017  A2MFARH7H7FSY1  B01HJ1INB0
# 3410015      5.0      True   12 6, 2016   AY532XZ00UTKN  B01HJ1INB0
# 3410016      4.0     False   12 6, 2016  A2VWQXWF1GO2ZE  B01HJ1INB0
# 3410017      5.0     False   11 6, 2016  A22AB77OD50U4M  B01HJ1INB0
# 3410018      4.0     False  08 21, 2016   ATGEMV4Z0GPOH  B01HJ1INB0
#
#                             style            reviewerName  \
# 0        {'Format:': ' VHS Tape'}                   Terri
# ...

# %%
df.to_csv('Movies_and_TV.csv')

# %%
df = df[['overall', 'verified', 'reviewTime', 'reviewID', 'asin', 'style', 'reviewerName', 'reviewText', 'summary', ]]

# %%
import random

# %%
random.seed(10)

# %%
subset_df = df.sample(100000)

# %%
subset_df.to_csv('Review_data_subset.csv')
